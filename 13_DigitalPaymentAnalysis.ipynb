# %% [markdown]
# <a href="https://colab.research.google.com/github/Sana-Shah-een/Artificial_Intelligence/blob/main/13_DigitalPaymentAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install numpy
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Load the dataset (Assuming the dataset is a CSV file)
df = pd.read_csv('/content/UPIData.csv')

# Display the first few rows of the dataset
df.head()
# Out:
#   Month-Year Month  Year  No.Of.Banks.Using.Upi  Volume.Of.Transaction.in.Mn  \
# 0     Feb-20   Feb  2020                    146                      1323.28
# 1     Jan-20   Jan  2020                    144                      1305.02
# 2     Dec-19   Dec  2019                    143                      1308.40
# 3     Nov-19   Nov  2019                    143                      1218.77
# 4     Oct-19   Oct  2019                    141                      1148.36
#
#   Amount.Of.Transaction  Amount.Of.Transaction.In.Bn
# 0           2,21,995.42                    2219.9542
# 1           2,16,242.97                    2162.4297
# 2           2,02,520.76                    2025.2076
# 3           1,89,229.09                    1892.2909
# 4           1,91,359.94                    1913.5994

# %%
# Get basic information about the dataset
print("\nBasic Information about the dataset:")
print(df.info())

# Summary statistics of the dataset
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Basic Information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Month-Year                   43 non-null     object
#  1   Month                        43 non-null     object
#  2   Year                         43 non-null     int64
#  3   No.Of.Banks.Using.Upi        43 non-null     int64
#  4   Volume.Of.Transaction.in.Mn  43 non-null     float64
#  5   Amount.Of.Transaction        43 non-null     object
#  6   Amount.Of.Transaction.In.Bn  43 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 2.5+ KB
# None
#
# Summary Statistics:
#               Year  No.Of.Banks.Using.Upi  Volume.Of.Transaction.in.Mn  \
# count    43.000000              43.000000                    43.000000
# mean   2017.860465              93.953488                   409.102326
# ...

# %%
# Check for missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Month-Year                     0
# Month                          0
# Year                           0
# No.Of.Banks.Using.Upi          0
# Volume.Of.Transaction.in.Mn    0
# Amount.Of.Transaction          0
# Amount.Of.Transaction.In.Bn    0
# dtype: int64

# %%
# Distribution of numerical features
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
for col in numerical_columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
sns.pairplot(df[numerical_columns])
plt.show()
