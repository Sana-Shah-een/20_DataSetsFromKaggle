# %% [markdown]
# <a href="https://colab.research.google.com/github/Sana-Shah-een/Artificial_Intelligence/blob/main/19_PizzaPlaceEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install numpy
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import datetime as dt

# %%
data_1=pd.read_csv("/content/order_details.csv")
data_1
# Out:
#        order_details_id  order_id       pizza_id  quantity
# 0                     1         1     hawaiian_m         1
# 1                     2         2  classic_dlx_m         1
# 2                     3         2  five_cheese_l         1
# 3                     4         2    ital_supr_l         1
# 4                     5         2     mexicana_m         1
# ...                 ...       ...            ...       ...
# 48615             48616     21348  ckn_alfredo_m         1
# 48616             48617     21348  four_cheese_l         1
# 48617             48618     21348   napolitana_s         1
# 48618             48619     21349     mexicana_l         1
# 48619             48620     21350      bbq_ckn_s         1
#
# [48620 rows x 4 columns]

# %%
data_2=pd.read_csv("/content/orders.csv")
data_2
# Out:
#        order_id        date      time
# 0             1  2015-01-01  11:38:36
# 1             2  2015-01-01  11:57:40
# 2             3  2015-01-01  12:12:28
# 3             4  2015-01-01  12:16:31
# 4             5  2015-01-01  12:21:30
# ...         ...         ...       ...
# 21345     21346  2015-12-31  20:51:07
# 21346     21347  2015-12-31  21:14:37
# 21347     21348  2015-12-31  21:23:10
# 21348     21349  2015-12-31  22:09:54
# 21349     21350  2015-12-31  23:02:05
#
# [21350 rows x 3 columns]

# %%
data_3=pd.read_csv("/content/pizza_types.csv",encoding='latin')
data_3
# Out:
#    pizza_type_id                                        name category  \
# 0        bbq_ckn                  The Barbecue Chicken Pizza  Chicken
# 1       cali_ckn                The California Chicken Pizza  Chicken
# 2    ckn_alfredo                   The Chicken Alfredo Pizza  Chicken
# 3      ckn_pesto                     The Chicken Pesto Pizza  Chicken
# 4     southw_ckn                 The Southwest Chicken Pizza  Chicken
# 5       thai_ckn                      The Thai Chicken Pizza  Chicken
# 6       big_meat                          The Big Meat Pizza  Classic
# 7    classic_dlx                    The Classic Deluxe Pizza  Classic
# 8       hawaiian                          The Hawaiian Pizza  Classic
# 9    ital_cpcllo                 The Italian Capocollo Pizza  Classic
# 10    napolitana                        The Napolitana Pizza  Classic
# 11   pep_msh_pep  The Pepperoni, Mushroom, and Peppers Pizza  Classic
# ...

# %%
data_4=pd.read_csv("/content/pizzas.csv")
data_4
# Out:
#          pizza_id pizza_type_id size  price
# 0       bbq_ckn_s       bbq_ckn    S  12.75
# 1       bbq_ckn_m       bbq_ckn    M  16.75
# 2       bbq_ckn_l       bbq_ckn    L  20.75
# 3      cali_ckn_s      cali_ckn    S  12.75
# 4      cali_ckn_m      cali_ckn    M  16.75
# ..            ...           ...  ...    ...
# 91  spinach_fet_m   spinach_fet    M  16.00
# 92  spinach_fet_l   spinach_fet    L  20.25
# 93   veggie_veg_s    veggie_veg    S  12.00
# 94   veggie_veg_m    veggie_veg    M  16.00
# 95   veggie_veg_l    veggie_veg    L  20.25
#
# [96 rows x 4 columns]

# %%
cdata=data_1.merge(data_2,how='inner',on='order_id')
cdata
# Out:
#        order_details_id  order_id       pizza_id  quantity        date  \
# 0                     1         1     hawaiian_m         1  2015-01-01
# 1                     2         2  classic_dlx_m         1  2015-01-01
# 2                     3         2  five_cheese_l         1  2015-01-01
# 3                     4         2    ital_supr_l         1  2015-01-01
# 4                     5         2     mexicana_m         1  2015-01-01
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  2015-12-31
# 48616             48617     21348  four_cheese_l         1  2015-12-31
# 48617             48618     21348   napolitana_s         1  2015-12-31
# 48618             48619     21349     mexicana_l         1  2015-12-31
# 48619             48620     21350      bbq_ckn_s         1  2015-12-31
#
#            time
# 0      11:38:36
# 1      11:57:40
# 2      11:57:40
# 3      11:57:40
# 4      11:57:40
# ...

# %%
cdata2=cdata.merge(data_4,how='inner',on='pizza_id')
cdata2
# Out:
#        order_details_id  order_id       pizza_id  quantity        date  \
# 0                     1         1     hawaiian_m         1  2015-01-01
# 1                   179        77     hawaiian_m         1  2015-01-02
# 2                   357       146     hawaiian_m         1  2015-01-03
# 3                   389       163     hawaiian_m         1  2015-01-03
# 4                   568       247     hawaiian_m         1  2015-01-04
# ...                 ...       ...            ...       ...         ...
# 48615             39733     17492  the_greek_xxl         1  2015-10-24
# 48616             41183     18139  the_greek_xxl         1  2015-11-05
# 48617             42718     18789  the_greek_xxl         1  2015-11-17
# 48618             43041     18919  the_greek_xxl         1  2015-11-19
# 48619             47490     20866  the_greek_xxl         1  2015-12-20
#
#            time pizza_type_id size  price
# 0      11:38:36      hawaiian    M  13.25
# ...

# %%
data=cdata2.merge(data_3,how='inner',on='pizza_type_id')
data
# Out:
#        order_details_id  order_id      pizza_id  quantity        date  \
# 0                     1         1    hawaiian_m         1  2015-01-01
# 1                   179        77    hawaiian_m         1  2015-01-02
# 2                   357       146    hawaiian_m         1  2015-01-03
# 3                   389       163    hawaiian_m         1  2015-01-03
# 4                   568       247    hawaiian_m         1  2015-01-04
# ...                 ...       ...           ...       ...         ...
# 48615             48176     21167  brie_carre_s         1  2015-12-27
# 48616             48244     21198  brie_carre_s         1  2015-12-28
# 48617             48311     21225  brie_carre_s         1  2015-12-29
# 48618             48456     21282  brie_carre_s         1  2015-12-31
# 48619             48527     21308  brie_carre_s         1  2015-12-31
#
#            time pizza_type_id size  price                  name category  \
# ...

# %%
#Display the first few rows of the dataset
data.head()
# Out:
#    order_details_id  order_id    pizza_id  quantity        date      time  \
# 0                 1         1  hawaiian_m         1  2015-01-01  11:38:36
# 1               179        77  hawaiian_m         1  2015-01-02  12:22:46
# 2               357       146  hawaiian_m         1  2015-01-03  14:22:10
# 3               389       163  hawaiian_m         1  2015-01-03  16:54:54
# 4               568       247  hawaiian_m         1  2015-01-04  20:55:29
#
#   pizza_type_id size  price                name category  \
# 0      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 1      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 2      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 3      hawaiian    M  13.25  The Hawaiian Pizza  Classic
# 4      hawaiian    M  13.25  The Hawaiian Pizza  Classic
#
#                                 ingredients
# 0  Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Sliced Ham, Pineapple, Mozzarella Cheese
# ...

# %%
# Get basic information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
#  4   date              48620 non-null  object
#  5   time              48620 non-null  object
#  6   pizza_type_id     48620 non-null  object
#  7   size              48620 non-null  object
#  8   price             48620 non-null  float64
#  9   name              48620 non-null  object
#  10  category          48620 non-null  object
#  11  ingredients       48620 non-null  object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 4.5+ MB

# %%
# Summary statistics of the dataset
data.describe()
# Out:
#        order_details_id      order_id      quantity         price
# count      48620.000000  48620.000000  48620.000000  48620.000000
# mean       24310.500000  10701.479761      1.019622     16.494132
# std        14035.529381   6180.119770      0.143077      3.621789
# min            1.000000      1.000000      1.000000      9.750000
# 25%        12155.750000   5337.000000      1.000000     12.750000
# 50%        24310.500000  10682.500000      1.000000     16.500000
# 75%        36465.250000  16100.000000      1.000000     20.250000
# max        48620.000000  21350.000000      4.000000     35.950000

# %%
# Check for missing values
data.isnull().sum()
# Out:
# order_details_id    0
# order_id            0
# pizza_id            0
# quantity            0
# date                0
# time                0
# pizza_type_id       0
# size                0
# price               0
# name                0
# category            0
# ingredients         0
# dtype: int64

# %%
data.set_index(['order_details_id'])
# Out:
#                   order_id      pizza_id  quantity        date      time  \
# order_details_id
# 1                        1    hawaiian_m         1  2015-01-01  11:38:36
# 179                     77    hawaiian_m         1  2015-01-02  12:22:46
# 357                    146    hawaiian_m         1  2015-01-03  14:22:10
# 389                    163    hawaiian_m         1  2015-01-03  16:54:54
# 568                    247    hawaiian_m         1  2015-01-04  20:55:29
# ...                    ...           ...       ...         ...       ...
# 48176                21167  brie_carre_s         1  2015-12-27  17:39:57
# 48244                21198  brie_carre_s         1  2015-12-28  15:39:02
# 48311                21225  brie_carre_s         1  2015-12-29  13:20:17
# 48456                21282  brie_carre_s         1  2015-12-31  12:09:59
# 48527                21308  brie_carre_s         1  2015-12-31  16:44:35
#
# ...

# %%
data['hour'] = pd.to_datetime(data['time'], infer_datetime_format=True).dt.hour
data.info()
# Out:
# <ipython-input-18-bb7e6f86712d>:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   data['hour'] = pd.to_datetime(data['time'], infer_datetime_format=True).dt.hour
# <ipython-input-18-bb7e6f86712d>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['hour'] = pd.to_datetime(data['time'], infer_datetime_format=True).dt.hour
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
# ...

# %%
data['Months'] = pd.to_datetime(data['date'], infer_datetime_format = True).dt.month
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
#  4   date              48620 non-null  object
#  5   time              48620 non-null  object
#  6   pizza_type_id     48620 non-null  object
#  7   size              48620 non-null  object
#  8   price             48620 non-null  float64
#  9   name              48620 non-null  object
#  10  category          48620 non-null  object
#  11  ingredients       48620 non-null  object
#  12  hour              48620 non-null  int32
#  13  Months            48620 non-null  int32
# dtypes: float64(1), int32(2), int64(3), object(8)
# memory usage: 4.8+ MB
# ...

# %%
sales_times = data['date'].value_counts()
sales_times
# Out:
# date
# 2015-11-26    261
# 2015-11-27    259
# 2015-10-15    258
# 2015-07-04    233
# 2015-07-03    207
#              ...
# 2015-12-27     87
# 2015-11-22     82
# 2015-12-29     77
# 2015-03-22     76
# 2015-12-30     73
# Name: count, Length: 358, dtype: int64

# %%
sales_hours = data['hour'].value_counts().sort_values(ascending=False)
sales_hours
# Out:
# hour
# 12    6543
# 13    6203
# 18    5359
# 17    5143
# 19    4350
# 16    4185
# 14    3521
# 20    3487
# 15    3170
# 11    2672
# 21    2528
# 22    1370
# 23      68
# 10      17
# 9        4
# Name: count, dtype: int64

# %% [markdown]
# How many customers do we have each day? Are there any peak hours?

# %%
total_customers=data.groupby('date')['order_id'].value_counts().sum()
total_customers
# Out:
# 48620

# %%
sales_hours.head(10).to_frame().plot(kind='bar',color='purple',figsize=(10,7))
plt.xlabel('Hours')
plt.ylabel('Total_Sales')
plt.title('Peak_Time_Chart')
# Out:
# Text(0.5, 1.0, 'Peak_Time_Chart')

# %% [markdown]
# How many pizzas are typically in order? Do we have any bestsellers?

# %%
average_pizzas_per_order = data.groupby('order_id')['pizza_id'].nunique().mean()
print(f"Average Pizza's per order is: {average_pizzas_per_order}")
# Out:
# Average Pizza's per order is: 2.2772833723653396

# %%
bestsellers = data['pizza_id'].value_counts().head(10)
plt.figure(figsize=(10,7))
bestsellers.plot(kind='bar',color='green', title='Top 10 Bestsellers')
plt.show()

# %%
data['price'].sum()
# Out:
# 801944.7

# %%
data['Months'].value_counts().sort_values(ascending=False)
# Out:
# Months
# 7     4301
# 5     4239
# 3     4186
# 11    4185
# 1     4156
# 8     4094
# 4     4067
# 6     4025
# 2     3892
# 12    3859
# 9     3819
# 10    3797
# Name: count, dtype: int64

# %%
data.groupby('Months').agg('Months').count().to_frame().plot(kind='bar',color='yellow', figsize=(15,8))
plt.ylabel('Number of pizzas orderd per Month')
plt.title('Number of pizzas sold per Month')
# Out:
# Text(0.5, 1.0, 'Number of pizzas sold per Month')

# %%
popularity=data['pizza_id'].value_counts().tail(10)
popularity
# Out:
# pizza_id
# spinach_supr_m    266
# the_greek_l       255
# ital_supr_s       194
# ital_veggie_l     190
# ckn_alfredo_l     187
# mexicana_s        160
# calabrese_s        99
# ckn_alfredo_s      96
# green_garden_l     94
# the_greek_xxl      28
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
popularity.plot(kind='bar',color='skyblue', title='Pizza Popularity')
plt.ylabel('orders')
plt.show()

# %% [markdown]
# **SUMMARY:**

# %% [markdown]
# **This dataset provides a comprehensive view of the pizza place's sales, allowing for various types of analysis to uncover trends and insights. The recommended analyses include:
#
# Customer Analysis: The number of customers served daily are 4850, along with pinpointing peak hours of operation.
# Order Analysis: Examining the typical number of pizzas per order and determining the best-selling items on the menu was found to be 'big_meat_s','thai_ckn_l','five_cheese_l'.
# Revenue Analysis: Calculating the total revenue generated over the year which is '801944.7000000001',identified seasonal trends in sales recorded from july month.
# Menu Optimization: Assessed which pizzas might need to be removed from the menu and found the least saled products as 'ckn_alfredo_s','green_garden_l','the_greek_xxl'.
# These analyses can offer valuable insights into customer behavior, sales performance, and opportunities for menu and marketing improvements.**
